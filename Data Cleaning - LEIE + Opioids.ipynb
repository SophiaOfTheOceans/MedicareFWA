# %% [markdown]
# # View Data

# %%
from google.colab import drive
import pandas as pd
from tqdm import tqdm_notebook

# %% [markdown]
# ## Examine data
# ### List of Excluded Individuals and Entities (LEIE)
# https://oig.hhs.gov/exclusions/exclusions_list.asp

# %%
drive.mount('/content/drive')
leie = pd.read_csv('/content/drive/MyDrive/ISYE 6740 Project Files/LEIE_UPDATED.csv')
# Out:
# Mounted at /content/drive
# <ipython-input-2-b5fdfd90f782>:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   leie = pd.read_csv('/content/drive/MyDrive/ISYE 6740 Project Files/LEIE_UPDATED.csv')

# %%
# Take a look at the first few rows
leie.head()
# Out:
#   LASTNAME FIRSTNAME MIDNAME                      BUSNAME         GENERAL  \
# 0      NaN       NaN     NaN    #1 MARKETING SERVICE, INC  OTHER BUSINESS
# 1      NaN       NaN     NaN             1 BEST CARE, INC  OTHER BUSINESS
# 2      NaN       NaN     NaN  101 FIRST CARE PHARMACY INC  OTHER BUSINESS
# 3      NaN       NaN     NaN     14 LAWRENCE AVE PHARMACY        PHARMACY
# 4      NaN       NaN     NaN     143 MEDICAL EQUIPMENT CO     DME COMPANY
#
#             SPECIALTY UPIN         NPI  DOB                        ADDRESS  \
# 0          SOBER HOME  NaN           0  NaN      239 BRIGHTON BEACH AVENUE
# 1  HOME HEALTH AGENCY  NaN           0  NaN  2161 UNIVERSITY AVENUE W, STE
# 2            PHARMACY  NaN  1972902351  NaN  C/O 609 W 191ST STREET, APT D
# 3                 NaN  NaN           0  NaN             14 LAWRENCE AVENUE
# 4        DME - OXYGEN  NaN           0  NaN               701 NW 36 AVENUE
#
#          CITY STATE    ZIP EXCLTYPE  EXCLDATE  REINDATE  WAIVERDATE WVRSTATE
# 0    BROOKLYN    NY  11235   1128a1  20200319         0           0      NaN
# 1  SAINT PAUL    MN  55114   1128b5  20230518         0           0      NaN
# 2    NEW YORK    NY  10040   1128b8  20220320         0           0      NaN
# 3   SMITHTOWN    NY  11787   1128a1  19880830         0           0      NaN
# 4       MIAMI    FL  33125   1128b7  19970620         0           0      NaN

# %% [markdown]
# - There are a lot of NaN values for all the segments of name (first, middle, last), UPIN, and DoB.
# - There are a lot of 0s for NPI, which might be a problem considering that this particular field is how we're planning to join the LEIE to other data...

# %%
# Take a look at the distribution of null columns.
# However, some numerical columns (NPI, REINDATE, WAIVERDATE) need additional scrutiny since it seems that they are inputted as 0s.
leie['NPI'] = leie['NPI'].replace(0,pd.NA)
leie['REINDATE'] = leie['REINDATE'].replace(0,pd.NA)
leie['WAIVERDATE'] = leie['WAIVERDATE'].replace(0,pd.NA)
leie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81471 entries, 0 to 81470
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LASTNAME    78143 non-null  object
#  1   FIRSTNAME   78142 non-null  object
#  2   MIDNAME     57497 non-null  object
#  3   BUSNAME     3326 non-null   object
#  4   GENERAL     81471 non-null  object
#  5   SPECIALTY   77344 non-null  object
#  6   UPIN        6134 non-null   object
#  7   NPI         7923 non-null   object
#  8   DOB         77281 non-null  float64
#  9   ADDRESS     81462 non-null  object
#  10  CITY        81470 non-null  object
#  11  STATE       81471 non-null  object
#  12  ZIP         81471 non-null  int64
#  13  EXCLTYPE    81471 non-null  object
#  14  EXCLDATE    81471 non-null  int64
#  15  REINDATE    0 non-null      object
#  16  WAIVERDATE  4 non-null      object
#  17  WVRSTATE    5 non-null      object
# dtypes: float64(1), int64(2), object(15)
# memory usage: 11.2+ MB

# %% [markdown]
# - REINDATE has no non-null values, which makes sense since LEIE does not include any providers that have been re-instated. Thus, we can probably delete those three columns.
# - ...We have a lot of Null NPIs, which will become a problem. Looks like we might have to consder alternative ethods to joining.

# %%
# Are the providers in here unique (i.e. Does each NPI only appear once.)
leie['NPI'].value_counts().head()
# Out:
# NPI
# 1508904798    3
# 1225072028    3
# 1801839139    3
# 1427503093    2
# 1992978571    2
# Name: count, dtype: int64

# %%
leie[leie['NPI']==1801839139]
# Out:
#           LASTNAME FIRSTNAME MIDNAME BUSNAME             GENERAL  \
# 16166  CHRISTENSEN      JOHN   PETER     NaN  PHYSICIAN (MD, DO)
# 16167  CHRISTENSEN      JOHN   PETER     NaN  PHYSICIAN (MD, DO)
# 16168  CHRISTENSEN      JOHN     NaN     NaN  PHYSICIAN (MD, DO)
#
#               SPECIALTY    UPIN         NPI         DOB  \
# 16166  GENERAL PRACTICE  K9897A  1801839139  19510925.0
# 16167  GENERAL PRACTICE     NaN  1801839139  19510925.0
# 16168  GENERAL PRACTICE  I53515  1801839139  19510925.0
#
#                             ADDRESS             CITY STATE    ZIP EXCLTYPE  \
# 16166           2900 N FLAGER DRIVE  WEST PALM BEACH    FL  33407   1128b4
# 16167  568 NE 255TH STREET, #D63217       CROSS CITY    FL  32628   1128a2
# 16168                P O BOX 019120            MIAMI    FL  33101   1128a1
#
#        EXCLDATE REINDATE WAIVERDATE WVRSTATE
# 16166  20131120     <NA>       <NA>      NaN
# 16167  20190220     <NA>       <NA>      NaN
# 16168  20170518     <NA>       <NA>      NaN

# %% [markdown]
# - NPI values are NOT unique; separate entry created for each violation?
# - One of the rows had blank MIDNAME and UPIN; can we fill in NPIs potentially? (No)

# %%
# Group by first name, last name, and state, then count unique NPI values
npi_counts = leie.groupby(['LASTNAME', 'FIRSTNAME', 'STATE', 'DOB'])['NPI'].nunique(dropna=False)
npi_counts[npi_counts > 1]
# Out:
# LASTNAME    FIRSTNAME  STATE  DOB
# BALTAZAR    RODNEY     MD     19621222.0    2
# BAUER       KURT       PA     19530416.0    2
# BERNHARD    LARRY      MD     19550619.0    2
# CARTER      CORNELIUS  OK     19640703.0    2
# CHIRBAN     ANGELO     AZ     19490422.0    2
# COZOLINO    CLIFFORD   NY     19590105.0    2
# CRESPIN     JOSE       FL     19550516.0    2
# DOSS        HEATHER    OK     19740708.0    2
# FERNANDEZ   EDUARDO    FL     19510818.0    2
# GILLHAM     LAMONT     NE     19720106.0    2
# HARDY       ANDREW     MI     19470608.0    2
# ILOUNO      GEORGE     CA     19600705.0    2
# JACOBSON    CLIFFORD   NY     19500105.0    2
# JOHNSON     DAVID      MI     19650916.0    2
# KOE         FRANK      IL     19500729.0    2
# KWON        OHUN       CA     19660223.0    2
# LAPRAIRIE   TERRA      OK     19760519.0    2
# LAVENDER    SHERYL     FL     19590405.0    2
# LY          HUNG       GA     19580101.0    2
# MCCUSKER    CHARLES    UT     19520215.0    2
# NADI        DAWER      NY     19580215.0    2
# NEWSOME     RAYMOND    TX     19541217.0    2
# OTUFALE     OTUKAYODE  TX     19591004.0    2
# PERRAULT    MARK       CA     19550419.0    2
# RACETTE     WENDALL    MI     19461006.0    2
# ROBERTS     JOSEPH     WI     19630510.0    2
# ROKHSAR     BENJAMIN   NY     19521209.0    2
# SABARATNAM  RUDRA      CA     19440620.0    2
# SAOUD       ALLEN      WV     19540529.0    2
# ST LUCIA    STEVEN     NY     19561125.0    2
# VAN WINKLE  DAVID      AR     19611123.0    2
# WICHINSKI   KEITH      TX     19710719.0    2
# WILLIAMS    SAM        CA     19311211.0    2
# WISNER      MARK       KS     19510618.0    2
# WORRELL     BRUCE      OH     19490727.0    2
# Name: NPI, dtype: int64

# %%
leie[(leie['LASTNAME']=='MCCUSKER') & (leie['FIRSTNAME']=='CHARLES')]
# Out:
#        LASTNAME FIRSTNAME MIDNAME BUSNAME               GENERAL   SPECIALTY  \
# 48790  MCCUSKER   CHARLES       F     NaN    PHYSICIAN (MD, DO)  PSYCHIATRY
# 48791  MCCUSKER   CHARLES     NaN     NaN  PSYCHOLOGIC PRACTICE  PSYCHOLOGY
#
#       UPIN         NPI         DOB                  ADDRESS            CITY  \
# 48790  NaN  1104028216  19520215.0    2689 S HIGHLAND DRIVE  SALT LAKE CITY
# 48791  NaN        <NA>  19520215.0  1627 S FOOTHILL DR, #10  SALT LAKE CITY
#
#       STATE    ZIP EXCLTYPE  EXCLDATE REINDATE WAIVERDATE WVRSTATE
# 48790    UT  84106   1128Aa  20141114     <NA>       <NA>      NaN
# 48791    UT  84108   1128b4  20020520     <NA>       <NA>      NaN

# %% [markdown]
# - Seems possible, certainly, but on other thought is it really necessary...? Since what we really want is a list of providers in the LEIE...

# %%
leie[(leie['NPI'].isnull()) & (leie['LASTNAME'].notnull())]
# Out:
#          LASTNAME   FIRSTNAME MIDNAME BUSNAME               GENERAL  \
# 3328        AAKER    DEBHANNA     NaN     NaN  EMPLOYEE - PRIVATE S
# 3329      AALDERS       NANCY   BLOCK     NaN              HOSPITAL
# 3330     AALTONEN    NICKOLAS       A     NaN  IND- LIC HC SERV PRO
# 3331        AAMIR    MUHAMMAD  SOHAIL     NaN        BUS OWNER/EXEC
# 3332        AARON       ALINA       A     NaN  IND- LIC HC SERV PRO
# ...           ...         ...     ...     ...                   ...
# 81466   ZWOLINSKI       AMBER    DAWN     NaN  IND- LIC HC SERV PRO
# 81467   ZYDERVELD        MARY     ANN     NaN              PHARMACY
# 81468     ZYLSTRA  CHRISTEENA    LYNN     NaN    NURSING PROFESSION
# 81469     ZYLSTRA       JAMES   PETER     NaN  REHAB FACILITY - GEN
# 81470  ZYWOCINSKI     CYNTHIA       A     NaN      OSTEOPATHIC PRAC
#
#                  SPECIALTY    UPIN   NPI         DOB  \
# 3328    HOME HEALTH AGENCY     NaN  <NA>  19820311.0
# 3329     NURSE/NURSES AIDE     NaN  <NA>  19640305.0
# 3330   PHARMACY TECHNICIAN     NaN  <NA>  19880123.0
# 3331    HOME HEALTH AGENCY     NaN  <NA>  19700910.0
# 3332     NURSE/NURSES AIDE     NaN  <NA>  19870209.0
# ...                    ...     ...   ...         ...
# 81466    NURSE/NURSES AIDE     NaN  <NA>  19870529.0
# 81467           TECHNICIAN     NaN  <NA>  19520825.0
# 81468    NURSE/NURSES AIDE     NaN  <NA>  19670724.0
# 81469             EMPLOYEE     NaN  <NA>  19550420.0
# 81470           OSTEOPATHY  F00244  <NA>  19630316.0
#
#                         ADDRESS              CITY STATE    ZIP EXCLTYPE  \
# 3328                2006 OAK ST       GRAND FORKS    ND  58201   1128a1
# 3329          9527 SOUTH KENTON          OAK LAWN    IL  60453   1128b4
# 3330           32 W PACIFIC AVE           SPOKANE    WA  99201   1128a4
# 3331        3956 COLUMBIA COURT  BLOOMFIELD HILLS    MI  48302   1128a1
# 3332   3325 N ROSE CIRCLE DRIVE           PHOENIX    AZ  85018   1128b4
# ...                         ...               ...   ...    ...      ...
# 81466       1238 PULASKI AVENUE     COAL TOWNSHIP    PA  17866   1128a1
# 81467   1358 MORNING GLORY TURN      RUCKERSVILLE    VA  22962   1128b4
# 81468       1816 NE 49TH STREET       KANSAS CITY    MO  64118   1128b4
# 81469  2305 MINNESOTA BLVD, S E          ST CLOUD    MN  56304   1128a2
# 81470       117 WHITE TAIL LANE         LANCASTER    MA   1523  1128b14
#
#        EXCLDATE REINDATE WAIVERDATE WVRSTATE
# 3328   20240820     <NA>       <NA>      NaN
# 3329   20030820     <NA>       <NA>      NaN
# 3330   20120419     <NA>       <NA>      NaN
# 3331   20170220     <NA>       <NA>      NaN
# 3332   20171019     <NA>       <NA>      NaN
# ...         ...      ...        ...      ...
# 81466  20160519     <NA>       <NA>      NaN
# 81467  20090219     <NA>       <NA>      NaN
# 81468  20100318     <NA>       <NA>      NaN
# 81469  20040920     <NA>       <NA>      NaN
# 81470  19990720     <NA>       <NA>      NaN
#
# [70714 rows x 18 columns]

# %% [markdown]
# - This has not yielded successfull results...god this is going to be a pain later on.

# %%
leie['SPECIALTY'].unique()
# Out:
# array(['SOBER HOME', 'HOME HEALTH AGENCY', 'PHARMACY', nan,
#        'DME - OXYGEN', 'MARKETING FIRM', 'TRANSPORTATION CO',
#        'DME - ORTHOTICS', 'DME - GENERAL', 'GENERAL PRACTICE',
#        'MENTAL/BEHAVIORAL HE', 'COMM MNTL HLTH CNTR', 'CONSULTING FIRM',
#        'ALLIED HEALTH RELATE', 'LAB - CLINICAL', 'PHYS THERAPY PROVIDE',
#        'CLINIC', 'DME - PROSTHETICS', 'COUNSELING CENTER',
#        'DME - HOME INFUSION', 'AMBULANCE COMPANY', 'CHIROPRACTIC PRACT',
#        'OPHTHALMOLOGY', 'DENTAL PRACTICE', 'DME - DIETARY SUPPLI',
#        'RESEARCH COMPANY', 'ALLERGIST/IMMUNOLOGY', 'HOSPITAL',
#        'INTERNAL MEDICINE', 'PSYCHOLOGIC PRACTICE',
#        'COMMUNITY HLTH CTR (', 'DME - HEARING AID', 'OPTOMETRIC PRACTICE',
#        'RADIOLOGY', 'LABORATORY', 'FAMILY PRACTICE', 'CHIROPRACTIC',
#        'DRUG COMPANY/SUPLIER', 'SUBSTANCE ABUSE REHA', 'LABORATORY-IDTF',
#        'SKILLED NURSING FAC', 'CARDIOLOGY', 'DME - WOUND CARE KIT',
#        'DME - UROLOGICAL SUP', 'GENERAL PRACTICE/FP',
#        'MANUF/LESSOR SUPP/EQ', 'DME - POWER VEHICLES', 'PSYCHIATRY',
#        'MANAGEMENT SVCS CO', 'OWNER/OPERATOR', 'NEUROLOGY', 'HEMATOLOGY',
#        'EMPLOYEE', 'ACCOUNTING FIRM', 'UROLOGY', 'DERMATOLOGY',
#        'EMERGENCY MEDICINE', 'ADULT HOME', 'SURGERY',
#        'ADULT DAY CARE FACIL', 'DME - LYMPHEDEMA PUM',
#        'RURAL HEALTH CLINIC', 'ONCOLOGY', 'NON-PROFIT ORGANIZAT',
#        'PAIN MANAGEMENT', 'COMPUTER RELATED', 'DME - INCONTINENCE K',
#        'PLASTIC SURGERY', 'PODIATRY PRACTICE', 'SUBCONTRACTOR (NON-H',
#        'HC CONGLOM - PARENT', 'NURSING FIRM', 'BILLING SERVICE CO',
#        'DME - TENS', 'NEPHROLOGY', 'MULTI-SPECIALTY',
#        'ACUPUNCTURE PRACTICE', 'NIH', 'DME - DIABETIC SUPPL',
#        'ASSISTED LIVING FACI', 'HOSPICE', 'COUNSELOR', 'ANESTHESIOLOGY',
#        'VENDOR', 'PERSONAL CARE PROVID', 'REHAB FACILITY - GEN',
#        "STATE GOV'T", 'HOTEL/LODGING', 'RADIOLOGY FACILITY',
#        'OTHER CONTRACTOR', 'DENTIST', 'NURSE/NURSES AIDE', 'PHARMACIST',
#        'PHARMACY TECHNICIAN', 'HEALTH CARE AIDE', 'RECIPT/BENEFICIARY',
#        'NO KNOWN AFFILIATION', 'NURSE PRACTITIONER (', 'THERAPIST',
#        'RHEUMATOLOGY', 'SALES/MARKET/RETAIL', 'HRSA', 'BUSINESS MANAGER',
#        'OSTEOPATHY', 'PODIATRY', 'PHYSICIAN PRACTICE (',
#        'INTERPRETER/TRANS', 'OFFICER/EXECUT/BOARD', 'PSYCHOLOGY',
#        'INTER CARE FACILITY', 'GYN/OBS', 'TECHNICIAN', 'PHYSICAL THERAPY',
#        'SOCIAL WORKER', 'RECRUITER/CAPPER', 'EMERGENCY MED TECH',
#        'EMPLOYEE - 14 & BELO', 'PHYSICIAN ASSISTANT',
#        'ACCOUNT/BOOKKPR/AUDI', 'OPTICIAN', 'CLERK/OTHER CLERICAL',
#        'BOARDING HOME', 'PARAMEDIC TECHNICIAN', 'REPRESENTATIVE PAYEE',
#        'PEDIATRICS', 'ORTHOPEDICS', 'INFECTIOUS DISEASE',
#        'GASTROENTEROLOGY', 'LICENSED PRACTITIONE', 'INFUSION THERAPY CLI',
#        'ADMINISTRATOR', 'EMPLOYEE - WAGE GRAD', 'RELATED', 'OPTOMETRY',
#        'OPTICAL PRACTICE', 'UNIVERSITY/COLLEGE', 'SUPERVISOR/FOREMAN',
#        'DME - TELEMARKETING', 'AUDIOLOGY', 'DENTAL HYGIENIST',
#        'PATHOLOGY', 'INSURANCE COMPANY', 'EMPLOYEE - GRADE UNK',
#        'AMBLNTRY SRGCL CNTR', 'TRIBAL AGENCY', 'ACF', 'HEALTH MAINT ORG',
#        'CMS', 'OTORHINOLARYNGOLOGY', 'SECUR OFFICER/GUARD',
#        'ENDOCRINOLOGY', 'PHLEBOTOMY', 'COMPTROLLER', 'ACUPUNCTURIST',
#        'OTHERS', 'DMERC', 'PULMONOLOGY', 'CONTRACTOR',
#        'OTHER FEDERAL AGENCY', "LOCAL GOV'T", 'CONSULTANT',
#        'THERAPEUTIC BOARDING', 'FOSTER CARE PROVIDER',
#        'MEDICARE ADV CONTR (', 'PAIN MGMT/PHYSIATRIS', 'GRANTEE',
#        'REGULATED INDUSTRY', "GOV'T INSUR RECIPIEN", 'LAWYER', 'OWNER',
#        'LABORER', 'LAW PRACTICE', 'GENETICS', 'ORTHOTIST/PROSTHETIS',
#        'PRIVATE CITIZEN', 'NATUROPATHY', 'IHS', 'MEDICAID MANAGED CAR',
#        'PHYS/DENT/HEAL/PROVI', 'AUDIOLOGY PRACTICE',
#        'CONTRACTING OFFICER', 'UNEMPLOYED', 'LAB-PHYSICIAN OWNED',
#        'ARCHITECT/ENGINEER', 'SAMHSA', 'PRINTING FIRM',
#        'ACCOUNTABLE CARE ORG', 'PHARMACY BENEFIT MAN',
#        'EMPLOYEE - MILITARY', 'PUBLIC ASSIST. RCPT.', 'ANESTHETIST',
#        'LAB-NON-INVASIV VASC', 'MEDICARE PART D CONT', 'TEACHER',
#        'SUBCONTRACTOR', 'AHRQ', 'GS 1-12', 'GERONTOLOGY', 'PROCTOLOGY',
#        'RENAL FACILITY', 'RSRCH SCNTST-EMPLYEE', 'PARENT CHLD SUP ENF',
#        'EMPLOYEE - GM/GS-15', 'LOAN RECIPIENT', 'ACL',
#        'CHECK CASHING STORE'], dtype=object)

# %% [markdown]
# - A lot of those categories are healthcare-related, but quite a few aren't. ('MARKETING FIRM', 'ACCOUNTING FIRM', 'LOCAL GOV'T', etc.)

# %%
# Find the NPI null rate for each specialty and order by lowest to highest
npi_null_rate_by_specialty = leie.groupby('SPECIALTY')['NPI'].apply(lambda x: x.isnull().sum() / len(x))
npi_null_rate_by_specialty = npi_null_rate_by_specialty.sort_values()
npi_null_rate_by_specialty.head(20)
# Out:
# SPECIALTY
# NATUROPATHY             0.000000
# INFECTIOUS DISEASE      0.000000
# PROCTOLOGY              0.000000
# PAIN MANAGEMENT         0.027624
# PHYSICIAN ASSISTANT     0.139665
# NURSE PRACTITIONER (    0.177665
# RHEUMATOLOGY            0.214286
# EMERGENCY MEDICINE      0.264957
# FAMILY PRACTICE         0.275253
# ACUPUNCTURIST           0.277778
# AUDIOLOGY               0.285714
# PHYSICAL THERAPY        0.331169
# MULTI-SPECIALTY         0.333333
# INTERNAL MEDICINE       0.357401
# GENERAL PRACTICE        0.364010
# CARDIOLOGY              0.379310
# ORTHOPEDICS             0.386364
# GENETICS                0.400000
# ANESTHESIOLOGY          0.400922
# GASTROENTEROLOGY        0.423077
# Name: NPI, dtype: float64

# %% [markdown]
# - Damn there's a lot of providers with missing NPIs...

# %%
# Investigating EXCLTYPE
leie['EXCLTYPE'].value_counts()
# Out:
# EXCLTYPE
# 1128b4      32631
# 1128a1      24902
# 1128a2       7916
# 1128a3       5614
# 1128a4       3472
# 1128b14      2199
# 1128b8       1497
# 1128b1        926
# 1128b5        813
# 1128b7        724
# 1128b3        337
# 1128Aa        150
# 1128b6         77
# 1128b2         66
# 1156           55
# 1128b15        34
# BRCH SA        22
# BRCH CIA       14
# 1128b11        11
# 1160            8
# 1128b16         2
# 1128b12         1
# Name: count, dtype: int64

# %% [markdown]
# Info regarding types of exclusions can be found here:
# - https://oig.hhs.gov/exclusions/authorities.asp
# - https://oig.hhs.gov/faqs/exclusions-faq/
#
# Generally:
# - **1128** - The scope of an exclusion under section 1128 of the Act is from all **Federal health care programs**, as defined in 42 CFR 1001.2. Federal health care programs include Medicare, Medicaid, and all other plans and programs that provide health benefits funded directly or indirectly by the United States (other than the Federal Employees Health Benefits Plan).
# - **1156** - The scope of an exclusion under section 1156 of the Act is from **Medicare and all State health care programs** as defined in section 1128(h) of the Act. Exclusions under section 1156 of the Act *do not reach other Federal programs*.

# %%
# Looking only at rows with non-null NPIs, visualize the top specialties.
leie[leie['NPI'].notnull()]['SPECIALTY'].value_counts().head(20)
# Out:
# SPECIALTY
# NURSE/NURSES AIDE       779
# GENERAL PRACTICE        774
# FAMILY PRACTICE         574
# INTERNAL MEDICINE       534
# CHIROPRACTIC            415
# COUNSELOR               358
# DENTIST                 326
# PHARMACIST              293
# PSYCHIATRY              242
# PAIN MANAGEMENT         176
# NURSE PRACTITIONER (    162
# PHYSICIAN ASSISTANT     154
# PSYCHOLOGY              152
# THERAPIST               151
# SOCIAL WORKER           151
# HEALTH CARE AIDE        140
# PODIATRY                136
# SURGERY                 135
# GYN/OBS                 133
# ANESTHESIOLOGY          130
# Name: count, dtype: int64

# %%
# Looking only at rows with non-null NPIs, visualize the top states.
leie[leie['NPI'].notnull()]['STATE'].value_counts().head(20)
# Out:
# STATE
# CA    1023
# FL     724
# NY     648
# OH     584
# TX     481
# PA     373
# MI     227
# IL     220
# WV     202
# NJ     198
# NV     169
# KY     168
# MD     153
# GA     139
# TN     137
# CO     137
# AZ     132
# WA     132
# AL     131
# OK     124
# Name: count, dtype: int64

# %% [markdown]
# - Maybe take a look at number of Medicare recipients?

# %%
# Find min and max excldates
print(leie['EXCLDATE'].min())
print(leie['EXCLDATE'].max())
# Out:
# 19770701
# 20250220

# %% [markdown]
# ### Opioids List

# %%
opioids = pd.read_excel('/content/drive/MyDrive/ISYE 6740 Project Files/Opioid_Drug_Lists_CY2018.xlsx')
opioids.head()
# Out:
#   Medicare Part D CY 2018 Opioids                    Unnamed: 1  \
# 0                             NaN                           NaN
# 1                             NaN                     Drug Name
# 2                             NaN                       ABSTRAL
# 3                             NaN  ACETAMIN-CAFF-DIHYDROCODEINE
# 4                             NaN         ACETAMINOPHEN-CODEINE
#
#                       Unnamed: 2
# 0                            NaN
# 1                   Generic Name
# 2               FENTANYL CITRATE
# 3  ACETAMINOPHEN/CAFF/DIHYDROCOD
# 4     ACETAMINOPHEN WITH CODEINE

# %%
opioids.tail()
# Out:
#    Medicare Part D CY 2018 Opioids  \
# 89                               *
# 90                             NaN
# 91                             NaN
# 92                             NaN
# 93                             NaN
#
#                                            Unnamed: 1              Unnamed: 2
# 89                                         ZOHYDRO ER  HYDROCODONE BITARTRATE
# 90                                              Note:                     NaN
# 91                              * Long-acting opioid.                     NaN
# 92  # Drug name includes NDC identifiers from the ...                     NaN
# 93  as well as NDC identifiers not included in the...                     NaN

# %% [markdown]
# ```
# * Long-acting opioid.
# # Drug name includes NDC identifiers from the Prescriber Drug Category List for opioids
# as well as NDC identifiers not included in the Prescriber Drug Category List for opioids.
# ```

# %%
opioids = opioids.iloc[2:90]
opioids
# Out:
#    Medicare Part D CY 2018 Opioids                    Unnamed: 1  \
# 2                              NaN                       ABSTRAL
# 3                              NaN  ACETAMIN-CAFF-DIHYDROCODEINE
# 4                              NaN         ACETAMINOPHEN-CODEINE
# 5                              NaN                         ACTIQ
# 6                                *                      ARYMO ER
# ..                             ...                           ...
# 85                             NaN                    VICODIN HP
# 86                             NaN                  XODOL 10-300
# 87                             NaN                 XODOL 7.5-300
# 88                               *                    XTAMPZA ER
# 89                               *                    ZOHYDRO ER
#
#                        Unnamed: 2
# 2                FENTANYL CITRATE
# 3   ACETAMINOPHEN/CAFF/DIHYDROCOD
# 4      ACETAMINOPHEN WITH CODEINE
# 5                FENTANYL CITRATE
# 6                MORPHINE SULFATE
# ..                            ...
# 85      HYDROCODONE/ACETAMINOPHEN
# 86      HYDROCODONE/ACETAMINOPHEN
# 87      HYDROCODONE/ACETAMINOPHEN
# 88            OXYCODONE MYRISTATE
# 89         HYDROCODONE BITARTRATE
#
# [88 rows x 3 columns]

# %%
opioids.columns = ['Addenda','Drug Name', 'Generic Name']
opioids['Long-acting opioid'] = opioids['Addenda'].apply(lambda x: 1 if '*' in x else 0)
opioids['NDC'] = opioids['Addenda'].apply(lambda x: 1 if '#' in x else 0)
opioids
# Out:
#    Addenda                     Drug Name                   Generic Name  \
# 2                                ABSTRAL               FENTANYL CITRATE
# 3           ACETAMIN-CAFF-DIHYDROCODEINE  ACETAMINOPHEN/CAFF/DIHYDROCOD
# 4                  ACETAMINOPHEN-CODEINE     ACETAMINOPHEN WITH CODEINE
# 5                                  ACTIQ               FENTANYL CITRATE
# 6        *                      ARYMO ER               MORPHINE SULFATE
# ..     ...                           ...                            ...
# 85                            VICODIN HP      HYDROCODONE/ACETAMINOPHEN
# 86                          XODOL 10-300      HYDROCODONE/ACETAMINOPHEN
# 87                         XODOL 7.5-300      HYDROCODONE/ACETAMINOPHEN
# 88       *                    XTAMPZA ER            OXYCODONE MYRISTATE
# 89       *                    ZOHYDRO ER         HYDROCODONE BITARTRATE
#
#     Long-acting opioid  NDC
# 2                    0    0
# 3                    0    0
# 4                    0    0
# 5                    0    0
# 6                    1    0
# ..                 ...  ...
# 85                   0    0
# 86                   0    0
# 87                   0    0
# 88                   1    0
# 89                   1    0
#
# [88 rows x 5 columns]

# %%
opioids = opioids.drop(columns=['Addenda'])

# %%
leie.to_csv('/content/drive/MyDrive/ISYE 6740 Project Files/leie_cleaned.csv', index=False)
opioids.to_csv('/content/drive/MyDrive/ISYE 6740 Project Files/opioids_cleaned.csv', index=False)
